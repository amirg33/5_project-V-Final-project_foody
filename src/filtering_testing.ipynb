# %%
import recipe_matcher
import pandas as pd
import ast
import utils

# %%
df = pd.read_csv("../data/Processed/recipes_with_ratings_restrictions.csv")
df.tags = df.tags.map(lambda x: ast.literal_eval(x))
df.steps = df.steps.map(lambda x: ast.literal_eval(x))
df.ingredients = df.ingredients.map(lambda x: ast.literal_eval(x))
df.nutrition = df.nutrition.map(lambda x: ast.literal_eval(x))
df.restrictions = df.restrictions.map(lambda x: ast.literal_eval(x))

# %%
ingredients_list = utils.aggregate_unique_lists(df, 'ingredients')

# %%
df["restrictions"]

# %%
# Example usage to filter out recipes that contain dairy or gluten
filtered_df = recipe_matcher.filter_restrictions(df, 'Dairy', 'Gluten') # it works!!

# %%
filtered_df.sample(10)

# %%
ingredients_list

# %%
filtered_recipes = recipe_matcher.optimized_realfooder_all_ingredients(df, ingredients_list, "'tomatoes'", "basil", "'dried dill seeds'" ,"'stella doro anisette toast'" )

# %%
filtered_recipes

# %%
filtered_recipes["ingredients"][0]

# %%
filtered_recipes = recipe_matcher.optimized_realfooder_all_ingredients(df, ingredients_list, "tomatoes", "basil")

# %%
filtered_recipes

# %%
filtered_recipes["ingredients"][0]

# %%
# Example usage
filtered_recipes_not_included = recipe_matcher.optimized_picky_eater_exclude_all(filtered_recipes, ingredients_list, "onions", "garlic", "garlic cloves")

# %%
filtered_recipes_not_included

# %%
# Example usage
filtered_recipes = recipe_matcher.All_restrictions(df, 
                                    restrictions=["Dairy"], 
                                    ingredients_list=ingredients_list, 
                                    required_ingredients=["tomatoes", "Basil", "ground beef"], 
                                    excluded_ingredients=["garlic", "water", "black pepper"])

# %%
filtered_recipes
# Out:
#                                                   name  recipe_id  minutes  \
# 0                                 our favorite lasagna     247474      120
# 1                                italian beef macaroni     207536       40
# 2                                 spicy shepherd s pie     282694       30
# 3                                  smoky bacon burgers      63215       25
# 4              8 for 8 broiled blt burgers for a bunch     499804      165
# ..                                                 ...        ...      ...
# 334                                easy taco casserole     252144       50
# 335                                   zippy taco salad      12848       30
# 336                            jacques stuffed cabbage     414242      240
# 337                                     ugandan matoke     235945       80
# 338  tsr version of burger king whopper by todd wilbur     112507        8
#
#                                                   tags  \
# 0    [time-to-make, course, main-ingredient, cuisin...
# 1    [60-minutes-or-less, time-to-make, course, mai...
# 2    [30-minutes-or-less, time-to-make, course, pre...
# 3    [30-minutes-or-less, time-to-make, course, mai...
# 4    [weeknight, time-to-make, course, main-ingredi...
# ..                                                 ...
# 334  [60-minutes-or-less, time-to-make, course, pre...
# 335  [30-minutes-or-less, time-to-make, course, mai...
# 336  [time-to-make, course, main-ingredient, cuisin...
# 337  [time-to-make, course, main-ingredient, cuisin...
# 338  [15-minutes-or-less, time-to-make, course, mai...
#
#                                          nutrition  n_steps  \
# 0    [824.4, 62.0, 62.0, 68.0, 104.0, 106.0, 21.0]       13
# 1      [596.7, 47.0, 27.0, 17.0, 71.0, 66.0, 14.0]        9
# 2      [634.7, 44.0, 22.0, 42.0, 70.0, 65.0, 20.0]       12
# 3       [426.5, 36.0, 16.0, 63.0, 54.0, 43.0, 8.0]       21
# 4        [404.3, 46.0, 8.0, 23.0, 52.0, 57.0, 1.0]       23
# ..                                             ...      ...
# 334     [547.0, 57.0, 31.0, 71.0, 75.0, 91.0, 5.0]       10
# 335       [345.2, 37.0, 5.0, 9.0, 55.0, 55.0, 1.0]       11
# 336    [531.2, 32.0, 62.0, 11.0, 51.0, 31.0, 17.0]       38
# 337      [468.7, 2.0, 228.0, 0.0, 11.0, 2.0, 40.0]       10
# 338     [437.7, 36.0, 24.0, 32.0, 52.0, 39.0, 9.0]        6
#
#                                                  steps  \
# 0    [in a dutch oven over high heat cook ground be...
# 1    [heat oil in saucepan, add the onions and garl...
# 2    [prepare mashed potatoes according to directio...
# 3    [combine the ground beef , onion , egg yolk , ...
# 4    [dice bacon into small pieces and fry in a ski...
# ..                                                 ...
# 334  [preheat oven to 350f, brown ground beef, drai...
# 335  [this is a great an easy recipe that can be th...
# 336  [remove the 12 outermost leaves from the cabba...
# 337  [peel the plantains , cut into cubes , sprinkl...
# 338  [preheat a barbecue grill on high, toast both ...
#
#                                            description  \
# 0    this recipe comes from the good housekeeping i...
# 1    such a pleaser with not just you adults, but t...
# 2    a kicked up version of the original.  it calls...
# 3    this one's for the guys or for you ladies who ...
# 4    save your money and shop wisely! i was able to...
# ..                                                 ...
# 334  this casserole is delish! my kids love it and ...
# 335  a twist to a regular taco salad. my mother has...
# 336  let me tell you what i went through to get thi...
# 337  matoke (or matooke) refer to the plantain or p...
# 338  i haven't tried it yet, but it is the recipe f...
#
#                                            ingredients  n_ingredients  \
# 0    [ground beef, onion, tomatoes, tomato paste, s...             15
# 1    [oil, ground beef, onions, garlic clove, dried...             12
# 2    [instant mashed potatoes, ground beef, onion, ...             11
# 3    [ground beef, onion, egg yolk, salt, pepper, l...             14
# 4    [ground beef, bacon, cheese, dried onion, seas...             10
# ..                                                 ...            ...
# 334  [ground beef, salsa, taco seasoning, salad dre...              8
# 335  [ground beef, lettuce, tomatoes, mild cheddar ...              6
# 336  [savoy cabbage, olive oil, onion, celery, garl...             16
# 337  [plantains, lemon, juice of, oil, onion, tomat...             11
# 338  [hamburger bun with sesame seeds, ground beef,...              9
#
#      average_rating  number_of_ratings  \
# 0              5.00                 15
# 1              5.00                  7
# 2              5.00                  7
# 3              5.00                  6
# 4              5.00                  6
# ..              ...                ...
# 334            1.67                  3
# 335            1.33                  3
# 336            0.00                  2
# 337            1.33                  6
# 338            1.17                  6
#
#                                                    url        cooking_time  \
# 0    https://www.food.com/recipe/our-favorite-lasag...  More than 1h 30min
# 1    https://www.food.com/recipe/italian-beef-macar...        About 30 min
# 2    https://www.food.com/recipe/spicy-shepherd-s-p...        About 30 min
# 3    https://www.food.com/recipe/smoky-bacon-burger...        About 15 min
# 4    https://www.food.com/recipe/8-for-8-broiled-bl...  More than 1h 30min
# ..                                                 ...                 ...
# 334  https://www.food.com/recipe/easy-taco-casserol...        About 45 min
# 335  https://www.food.com/recipe/zippy-taco-salad-1...        About 30 min
# 336  https://www.food.com/recipe/jacques-stuffed-ca...  More than 1h 30min
# 337  https://www.food.com/recipe/ugandan-matoke-235945        About 75 min
# 338  https://www.food.com/recipe/tsr-version-of-bur...        About 15 min
#
#     ingredient_group  weighted_rating                        restrictions
# 0              10-20         4.923095  [Vegetarian, Vegan, Gluten, Dairy]
# 1              10-20         4.854734  [Vegan, Vegetarian, Dairy, Gluten]
# 2              10-20         4.854734          [Vegan, Vegetarian, Dairy]
# 3              10-20         4.836576          [Vegan, Vegetarian, Dairy]
# 4               5-10         4.836576          [Dairy, Vegan, Vegetarian]
# ..               ...              ...                                 ...
# 334             5-10         2.740522          [Dairy, Vegetarian, Vegan]
# 335             5-10         2.536522          [Vegetarian, Vegan, Dairy]
# 336            10-20         2.173152                 [Vegan, Vegetarian]
# 337            10-20         2.084076                 [Vegan, Vegetarian]
# 338             5-10         1.964076                 [Vegan, Vegetarian]
#
# [339 rows x 17 columns]
