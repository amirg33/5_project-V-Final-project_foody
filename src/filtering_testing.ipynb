# %%
import recipe_matcher
import pandas as pd
import ast
import utils

# %%
df = pd.read_csv("../data/Processed/recipes_with_ratings_restrictions.csv")
df.tags = df.tags.map(lambda x: ast.literal_eval(x))
df.steps = df.steps.map(lambda x: ast.literal_eval(x))
df.ingredients = df.ingredients.map(lambda x: ast.literal_eval(x))
df.nutrition = df.nutrition.map(lambda x: ast.literal_eval(x))
df.restrictions = df.restrictions.map(lambda x: ast.literal_eval(x))

# %%
ingredients_list = utils.aggregate_unique_lists(df, 'ingredients')

# %%
df["restrictions"]

# %%
# Example usage to filter out recipes that contain dairy or gluten
filtered_df = recipe_matcher.filter_restrictions(df, 'Dairy', 'Gluten') # it works!!

# %%
filtered_df.sample(10)

# %%
ingredients_list

# %%
filtered_recipes = recipe_matcher.optimized_realfooder(df, ingredients_list, "'tomatoes'", "basil", "'dried dill seeds'" ,"'stella doro anisette toast'" )

# %%
filtered_recipes

# %%
filtered_recipes["ingredients"][0]

# %%
filtered_recipes = recipe_matcher.optimized_realfooder_all_ingredients(df, ingredients_list, "tomatoes", "basil")

# %%
filtered_recipes

# %%
filtered_recipes["ingredients"][0]

# %%
# Example usage
filtered_recipes_not_included = recipe_matcher.optimized_picky_eater_exclude_all(filtered_recipes, ingredients_list, "onions", "garlic", "garlic cloves")

# %%
filtered_recipes_not_included

# %%
# Example usage
filtered_recipes = recipe_matcher.All_restrictions(df, 
                                    restrictions=["Dairy"], 
                                    ingredients_list=ingredients_list, 
                                    required_ingredients=["tomatoes", "Basil", "ground beef"], 
                                    excluded_ingredients=["garlic", "water", "black pepper"])

# %%
filtered_recipes
# Out:
#                                        name  recipe_id  minutes  \
# 0                                   5 tacos     500166       20
# 1        denny s vegetable beef barley soup      11363       40
# 2                  1 3 pound squeeze burger     344373       25
# 3                         5 spice beef rice     309594       40
# 4                  7 layer kind of taco dip     391589       60
# ..                                      ...        ...      ...
# 334                        zippy taco salad      12848       30
# 335  zoo tosopy paraguayan ground beef stew     468010       50
# 336        zucchini and ground beef lasagna     157263       60
# 337                        zucchini mussaka      18622       80
# 338                       zucchini surprise     385128       40
#
#                                                   tags  \
# 0    [weeknight, 30-minutes-or-less, time-to-make, ...
# 1    [60-minutes-or-less, time-to-make, course, mai...
# 2    [30-minutes-or-less, time-to-make, course, mai...
# 3    [lactose, 60-minutes-or-less, time-to-make, co...
# 4    [60-minutes-or-less, time-to-make, course, pre...
# ..                                                 ...
# 334  [30-minutes-or-less, time-to-make, course, mai...
# 335  [60-minutes-or-less, time-to-make, course, mai...
# 336  [60-minutes-or-less, time-to-make, course, mai...
# 337  [weeknight, time-to-make, course, main-ingredi...
# 338  [weeknight, 60-minutes-or-less, time-to-make, ...
#
#                                             nutrition  n_steps  \
# 0            [249.4, 26.0, 4.0, 6.0, 39.0, 39.0, 0.0]        5
# 1          [244.5, 17.0, 10.0, 75.0, 39.0, 17.0, 5.0]        4
# 2       [975.7, 112.0, 21.0, 43.0, 134.0, 204.0, 3.0]       10
# 3         [503.9, 35.0, 17.0, 25.0, 53.0, 38.0, 15.0]        7
# 4           [446.3, 50.0, 8.0, 25.0, 42.0, 93.0, 5.0]       11
# ..                                                ...      ...
# 334          [345.2, 37.0, 5.0, 9.0, 55.0, 55.0, 1.0]       11
# 335        [446.7, 37.0, 51.0, 3.0, 48.0, 38.0, 11.0]        8
# 336      [692.7, 61.0, 65.0, 43.0, 95.0, 100.0, 10.0]       11
# 337  [1175.9, 121.0, 184.0, 236.0, 88.0, 222.0, 29.0]       10
# 338        [314.3, 27.0, 40.0, 14.0, 47.0, 33.0, 5.0]        9
#
#                                                  steps  \
# 0    [cook meat, add taco seasoning, place meat int...
# 1    [brown ground beef , add vegetables , tomatoes...
# 2    ["divide the meat into 3 evenly sized burgers ...
# 3    [brown meat and onion, stir in seasonings , so...
# 4    [in a skillet over medium high heat cook groun...
# ..                                                 ...
# 334  [this is a great an easy recipe that can be th...
# 335  [place beef in a large pot or dutch oven, add ...
# 336  [cut zucchini into strips , 1 / 4-inch thick, ...
# 337  [also need moistened parchment paper to cover,...
# 338  [brown ground beef in large skillet, drain off...
#
#                                            description  \
# 0                           costs about $5.00 to make.
# 1    this easy to make soup is very close to the ve...
# 2    adapted from a recipe courtesy of squeeze inn....
# 3    this recipe came from my husband's grandmother...
# 4    i took a bunch of 7 layer dips and a couple of...
# ..                                                 ...
# 334  a twist to a regular taco salad. my mother has...
# 335  adapted from the woman's day encyclopedia of c...
# 336  in a welcome change from all of the heavy lasa...
# 337    turkish casserole. very unusual and very tasty.
# 338  we really enjoy this during zucchini season. m...
#
#                                            ingredients  n_ingredients  \
# 0    [ground beef, taco seasoning, taco shells, let...              9
# 1    [ground beef, frozen mixed vegetables, barley,...              5
# 2    [ground beef, "lawrys seasoned salt", mild che...             10
# 3    [ground beef, onion, pepper, bay leaf, garlic ...             11
# 4    [cream cheese, refried beans, sour cream, four...              9
# ..                                                 ...            ...
# 334  [ground beef, lettuce, tomatoes, mild cheddar ...              6
# 335  [ground beef, cold water, oil, onions, tomatoe...              9
# 336  [zucchini, olive oil, garlic cloves, onion, gr...             16
# 337  [zucchini, butter, onions, ground beef, tomato...              9
# 338  [ground beef, zucchini, onion, bell pepper, to...             10
#
#      average_rating  number_of_ratings  \
# 0              4.00                  1
# 1              3.11                  9
# 2              5.00                  4
# 3              4.50                  4
# 4              3.00                  1
# ..              ...                ...
# 334            1.33                  3
# 335            4.00                  2
# 336            4.00                  1
# 337            4.00                  1
# 338            5.00                  1
#
#                                                    url  cooking_time  \
# 0           https://www.food.com/recipe/5-tacos-500166  About 15 min
# 1    https://www.food.com/recipe/denny-s-vegetable-...  About 30 min
# 2    https://www.food.com/recipe/1-3-pound-squeeze-...  About 15 min
# 3    https://www.food.com/recipe/5-spice-beef-rice-...  About 30 min
# 4    https://www.food.com/recipe/7-layer-kind-of-ta...  About 60 min
# ..                                                 ...           ...
# 334  https://www.food.com/recipe/zippy-taco-salad-1...  About 30 min
# 335  https://www.food.com/recipe/zoo-tosopy-paragua...  About 45 min
# 336  https://www.food.com/recipe/zucchini-and-groun...  About 60 min
# 337  https://www.food.com/recipe/zucchini-mussaka-1...  About 75 min
# 338  https://www.food.com/recipe/zucchini-surprise-...  About 30 min
#
#     ingredient_group                 restrictions
# 0               5-10   [Vegetarian, Vegan, Dairy]
# 1                0-5  [Vegetarian, Vegan, Gluten]
# 2               5-10   [Vegan, Dairy, Vegetarian]
# 3              10-20          [Vegan, Vegetarian]
# 4               5-10   [Dairy, Vegetarian, Vegan]
# ..               ...                          ...
# 334             5-10   [Vegetarian, Vegan, Dairy]
# 335             5-10          [Vegan, Vegetarian]
# 336            10-20   [Vegetarian, Vegan, Dairy]
# 337             5-10   [Vegetarian, Vegan, Dairy]
# 338             5-10   [Vegetarian, Vegan, Dairy]
#
# [339 rows x 16 columns]
